# %%
import pandas as pd
from tokenizers import ByteLevelBPETokenizer
import json
from pathlib import Path

# %%
path = Path('/home/soon/datasets/deepfashion_multimodal')
captions = json.load(open(path/'captions.json'))

# %%
texts = list(captions.values())

# %%
texts[0]
# Out:
# 'The lower clothing is of long length. The fabric is cotton and it has plaid patterns.'

# %%
tokenizer = ByteLevelBPETokenizer(lowercase=True)
tokenizer.train_from_iterator(texts, special_tokens=["[EOS]"])
tokenizer
#tokenizer.save("../tokenizer-mm.json")

# %%
# Out:
# Tokenizer(vocabulary_size=560, model=ByteLevelBPE, add_prefix_space=False, lowercase=True, dropout=None, unicode_normalizer=None, continuing_subword_prefix=None, end_of_word_suffix=None, trim_offsets=False)

# %%
tokenizer.get_vocab()
# Out:
# {'M': 45,
#  'ele': 443,
#  'ĳ': 240,
#  'Ċ': 199,
#  'ħ': 228,
#  'ped': 492,
#  'c': 67,
#  'Ġits': 395,
#  '-': 13,
#  'Ġor': 550,
#  'ý': 186,
#  'u': 85,
#  'Ġlower': 481,
#  'Ġgen': 489,
#  '|': 92,
#  'G': 39,
#  'al': 466,
#  '«': 105,
#  '§': 101,
#  ';': 27,
#  'irt': 311,
#  'ric': 284,
#  '=': 29,
#  '¡': 95,
#  'Ç': 132,
#  'ê': 167,
#  ':': 26,
#  'his': 528,
#  '8': 24,
#  'K': 43,
#  'ir': 309,
#  'ings': 516,
#  'í': 170,
#  'kirt': 501,
#  'Ï': 140,
#  'ì': 169,
#  'Ġpure': 349,
#  'oin': 378,
#  'ù': 182,
#  'Æ': 131,
#  'Ġgrap': 376,
#  'Ġlong': 361,
#  'ã': 160,
#  'ic': 278,
#  '$': 4,
#  'Ġwears': 298,
#  'ģ': 224,
#  'Ġshorts': 383,
#  'eglasses': 558,
#  'Ġfurr': 545,
#  'Ġof': 334,
#  '¯': 108,
#  'A': 33,
#  'ing': 279,
#  'H': 40,
#  '~': 94,
#  'Ġsleeveless': 445,
#  'Ĉ': 197,
#  'E': 37,
#  'quarter': 540,
#  'N': 46,
#  'ä': 161,
#  'ė': 212,
#  'Ġmediu': 471,
#  'Ġden': 404,
#  'leev': 317,
#  '?': 31,
#  'ck': 312,
#  'ñ': 174,
#  'Ġw': 262,
# ...

# %%
tokenizer
# Out:
# Tokenizer(vocabulary_size=938, model=ByteLevelBPE, add_prefix_space=False, lowercase=True, dropout=None, unicode_normalizer=None, continuing_subword_prefix=None, end_of_word_suffix=None, trim_offsets=False)

# %%
tokenizer
# Out:
# Tokenizer(vocabulary_size=560, model=ByteLevelBPE, add_prefix_space=False, lowercase=True, dropout=None, unicode_normalizer=None, continuing_subword_prefix=None, end_of_word_suffix=None, trim_offsets=False)
